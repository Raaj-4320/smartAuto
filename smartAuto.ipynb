# %% [markdown]
# 1. manufacturer - name of the car manufacturer
# 2. model - name of the car model
# 3. year - the year when the car was produced
# 4. mileage - the number of miles the car has traveled since production
# 5. engine - car engine
# 6. transmission - type of the car's transmission
# 7. drivetrain - type of the car's drivetrain
# 8. fuel_type - type of fuel that the car consumes
# 9. mpg - the number of miles a car can travel using one gallon of fuel (miles per gallon)
# 10. exterior_color - car exterior color
# 11. interior_color - car interior color
# 12. accidents_or_damage - whether the car was involved in accidents
# 13. one_owner - whether the car was owned by one person
# 14. personal_use_only - whether the car was used only for personal purposes
# 15. seller_name - name of the seller
# 16. seller_rating - seller's rating
# 17. driver_rating - car rating given by drivers
# 18. driver_reviews_num - the number of car reviews left by drivers
# 19. price_drop - price reduction from the initial price
# 20. price - car price
#
# ### There will be two sides of the product, i.e. buyer side and seller side, for which we are going to take this dataset into consideration for different features.
#
# To approach the project in a effective way,we need to take many thigs into consideration, from the data viewpoint we need to check the missing values, number of missing values, reason behind the missing values, handle missing values, number of unique values in each feature, feature importance & description of each feaure, encoding the records based on their nature, categorizing features, split the data into train and test, train the algorithm, get the model ready for further process.
#
# Then comes the recommendation system, for which we can use the same cleaned data and create a recommendation system which performs according to the aim of the project.

# %%
# # Import the drive module
# from google.colab import drive

# # Mount the drive
# drive.mount('/content/drive')

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df.sample(5)
# Out:
#        manufacturer         model  year  mileage                      engine  \
# 33946           BMW         330 i  2018  54499.0  2.0L I4 16V GDI DOHC Turbo
# 35995           BMW  330 i xDrive  2020  21534.0  2.0L I4 16V GDI DOHC Turbo
# 419358          Kia    Sportage S  2020  32275.0        2.4L I4 16V GDI DOHC
# 302628        Honda   Pilot Sport  2022   3386.0        3.5L V6 24V GDI SOHC
# 728239   Volkswagen   Beetle 2.5L  2013  46874.0       2.5L I5 20V MPFI DOHC
#
#              transmission         drivetrain fuel_type    mpg  \
# 33946   8-Speed Automatic   Rear-wheel Drive  Gasoline  24-34
# 35995   8-Speed Automatic    All-wheel Drive  Gasoline  25-34
# 419358  6-Speed Automatic    All-wheel Drive  Gasoline  22-26
# 302628  9-Speed Automatic    All-wheel Drive  Gasoline  19-26
# 728239  6-Speed Automatic  Front-wheel Drive  Gasoline  21-27
#
#                 exterior_color  ... accidents_or_damage  one_owner  \
# ...

# %%
df.describe()
# Out:
#                 year       mileage  accidents_or_damage      one_owner  \
# count  762091.000000  7.615850e+05        737879.000000  730608.000000
# mean     2017.791398  5.578169e+04             0.228616       0.561969
# std         5.110532  4.355788e+04             0.419942       0.496145
# min      1915.000000  0.000000e+00             0.000000       0.000000
# 25%      2016.000000  2.328700e+04             0.000000       0.000000
# 50%      2019.000000  4.559600e+04             0.000000       1.000000
# 75%      2021.000000  7.836500e+04             0.000000       1.000000
# max      2024.000000  1.119067e+06             1.000000       1.000000
#
#        personal_use_only  seller_rating  driver_rating  driver_reviews_num  \
# count      737239.000000  548118.000000  730459.000000       762091.000000
# mean            0.657212       4.158568       4.623523           89.550900
# std             0.474642       0.805741       0.276902          115.082266
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 762091 entries, 0 to 762090
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   manufacturer         762091 non-null  object
#  1   model                762091 non-null  object
#  2   year                 762091 non-null  int64
#  3   mileage              761585 non-null  float64
#  4   engine               747041 non-null  object
#  5   transmission         752187 non-null  object
#  6   drivetrain           740529 non-null  object
#  7   fuel_type            739164 non-null  object
#  8   mpg                  620020 non-null  object
#  9   exterior_color       753232 non-null  object
#  10  interior_color       705116 non-null  object
#  11  accidents_or_damage  737879 non-null  float64
#  12  one_owner            730608 non-null  float64
#  13  personal_use_only    737239 non-null  float64
# ...

# %%
# First result: Total null values for each feature
null_counts = df.isnull().sum()
null_df = pd.DataFrame(null_counts, columns=["Missing Values"])

# Second result: Total unique values for each feature
unique_values = df.nunique().reset_index()
unique_values.columns = ["Feature", "Unique Values"]

# Combine the two DataFrames
combined_df = pd.merge(unique_values, null_df, left_on="Feature", right_index=True)

# Display the combined DataFrame
print(combined_df)
# Out:
#                 Feature  Unique Values  Missing Values
# 0          manufacturer             30               0
# 1                 model          12187               0
# 2                  year            100               0
# 3               mileage         158751             506
# 4                engine           6903           15050
# 5          transmission           1313            9904
# 6            drivetrain             33           21562
# 7             fuel_type             36           22927
# 8                   mpg            865          142071
# 9        exterior_color           7681            8859
# 10       interior_color           4679           56975
# 11  accidents_or_damage              2           24212
# 12            one_owner              2           31483
# 13    personal_use_only              2           24852
# 14          seller_name          18254            8593
# 15        seller_rating             41          213973
# ...

# %% [markdown]
# ### Let's start by projecting the features which has missing values and try to figure out what do they have in common
# ### By doing so we can understand if there is any underlying pattern, we can handle missing values in a proper method rather than just using random methods

# %% [markdown]
# # Mileage - Missing Values
# * Right now we have taken 5 random samples from missing valuues the feature mileage for analysis.
#
# * From the initial analysis, it seems the values are missing at random, there are no correlation between the values which are missing and the other feature of the same records.

# %%
df[df['mileage'].isnull()].sample(5)
# Out:
#          manufacturer                        model  year  mileage  \
# 535229  Mercedes-Benz                 C-Class C230  2006      NaN
# 650042         Subaru              Crosstrek Sport  2023      NaN
# 537131  Mercedes-Benz          CLA 250 Base 4MATIC  2023      NaN
# 516194  Mercedes-Benz          GLC 300 Base 4MATIC  2022      NaN
# 190432           Ford  Explorer Sport Trac Limited  2008      NaN
#
#                             engine       transmission        drivetrain  \
# 535229       2.5L V6 24V MPFI DOHC                NaN  Rear-wheel Drive
# 650042        2.5L H4 16V GDI DOHC      Automatic CVT   All-wheel Drive
# 537131  2.0L I4 16V GDI DOHC Turbo  7-Speed Automatic   All-wheel Drive
# 516194  2.0L I4 16V GDI DOHC Turbo  9-Speed Automatic   All-wheel Drive
# 190432       4.0L V6 12V MPFI SOHC  5-Speed Automatic  Rear-wheel Drive
#
#        fuel_type    mpg       exterior_color      interior_color  \
# 535229  Gasoline  21-29                Black                 NaN
# ...

# %%
# Let's analyse which cars or their models are missing the most number of mileage values.

# %%
null_mileage = df[df['mileage'].isnull()]

# %%
# Calculate value counts
value_counts = null_mileage['manufacturer'].value_counts().reset_index()
value_counts.columns = ['manufacturer', 'Count']  # Rename columns for better visualization

# Create bar plot with plotly
fig = px.bar(value_counts, x='manufacturer', y='Count', title="Value Counts Plot", text='Count')

# Customize appearance (optional)
fig.update_traces(textposition='outside')  # Show count numbers outside the bars
fig.update_layout(xaxis_title="manufacturer", yaxis_title="Count", showlegend=False)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# For this scenario we can fill these cars mileage, with the value of their respective cars model which are having mileage values,
# We can use these records as a reference to put which generates an organic like values to fill the null mileage values
# For that we need supportive feature which are numerical and could decide whether what is the mileage of the car depending on the other features
# And in achieving this it may happen that the other features which we are taking as a reference are having null values, the solution could be to drop
# those values and carry forward with the null values filling of  mileage.

# %%
# To achieve this we need to get the data where the manufacturer is Porsche and the mileage values are notnull

# getting the manufacturer = Porsche

filtered_df = df[(df['manufacturer'] == 'Porsche') & (df['mileage'].notnull())].sample(5)

filtered_df
# Out:
#        manufacturer                    model  year  mileage  \
# 616512      Porsche                      911  2020  18864.0
# 607838      Porsche                  Cayenne  2014  87423.0
# 615591      Porsche  911 Carrera S Cabriolet  2006  74205.0
# 608999      Porsche              718 Boxster  2021   6284.0
# 612710      Porsche               Macan Base  2021  30000.0
#
#                             engine                       transmission  \
# 616512                         NaN                          Automatic
# 607838        3.6L V6 24V GDI DOHC                  8-Speed Automatic
# 615591       3.8L H6 24V MPFI DOHC                     6-Speed Manual
# 608999  2.0L H4 16V GDI DOHC Turbo  7-Speed Automatic with Auto-Shift
# 612710  2.0L I4 16V GDI DOHC Turbo  7-Speed Automatic with Auto-Shift
#
#               drivetrain fuel_type    mpg      exterior_color  \
# 616512               NaN       NaN    NaN       Racing Yellow
# ...

# %%
filtered

# %%
filtered_df.size
# Out:
# 0

# %%
# Checking whether manufacturer has how many values for each brand

# df['manufacturer'].value_counts()

# Calculate value counts
value_counts = df['manufacturer'].value_counts().reset_index()
value_counts.columns = ['manufacturer', 'Count']  # Rename columns for better visualization

# Create bar plot with plotly
fig = px.bar(value_counts, x='manufacturer', y='Count', title="Value Counts Plot", text='Count')

# Customize appearance (optional)
fig.update_traces(textposition='outside')  # Show count numbers outside the bars
fig.update_layout(xaxis_title="manufacturer", yaxis_title="Count", showlegend=False)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### How many unique models does each manufacturere is having

# %%
# Group by manufacturer and count unique models
models_per_brand = df.groupby('manufacturer')['model'].nunique().reset_index()
models_per_brand.columns = ['manufacturer', 'unique_models']

# Display the result
print(models_per_brand)
# Out:
#      manufacturer  unique_models
# 0           Acura            242
# 1            Audi            558
# 2             BMW            648
# 3           Buick            215
# 4        Cadillac            320
# 5       Chevrolet            840
# 6        Chrysler            130
# 7           Dodge            437
# 8            Ford           1156
# 9             GMC            296
# 10          Honda            253
# 11        Hyundai            241
# 12       INFINITI            255
# 13         Jaguar            258
# 14           Jeep            415
# 15            Kia            380
# 16     Land Rover            330
# 17          Lexus            444
# 18        Lincoln            153
# 19          Mazda            243
# 20  Mercedes-Benz            975
# 21     Mitsubishi            183
# 22         Nissan            402
# 23        Porsche            289
# 24            RAM            183
# 25         Subaru            332
# 26          Tesla            121
# ...

# %%
# Create bar chart
fig = px.bar(models_per_brand,
             x='manufacturer',
             y='unique_models',
             title="Number of Unique Models Per Manufacturer",
             text='unique_models')

# Customize bar chart
fig.update_traces(textposition='outside')  # Display counts above bars
fig.update_layout(xaxis_title="Manufacturer",
                  yaxis_title="Number of Models")

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Which model is most popular for reselling in every brands?

# %%
# Group by manufacturer and model to count occurrences
model_counts = df.groupby(['manufacturer', 'model']).size().reset_index(name='count')

# Get the most popular model for each brand
most_popular_per_brand = model_counts.loc[model_counts.groupby('manufacturer')['count'].idxmax()]

# Display the result
print(most_popular_per_brand)
# Out:
#         manufacturer                                    model  count
# 129            Acura                   RDX Technology Package    830
# 504             Audi                     Q5 2.0T Premium Plus   1087
# 1297             BMW                             X3 xDrive30i   1481
# 1494           Buick                         Encore Preferred   2139
# 1948        Cadillac                               XT5 Luxury   1544
# 2497       Chevrolet                                Malibu LT   1905
# 2918        Chrysler                       Pacifica Touring-L   2057
# 3180           Dodge                        Grand Caravan SXT   1907
# 4075            Ford                                Fusion SE   3172
# 4814             GMC                             Yukon Denali   1805
# 5004           Honda                             Odyssey EX-L   2391
# 5129         Hyundai                              Elantra SEL   1449
# 5559        INFINITI                                QX60 Luxe   1359
# ...

# %%
# Plot using Plotly
fig = px.bar(most_popular_per_brand,
             x='manufacturer',
             y='count',
             color='model',  # Differentiate bars by model
             title="Most Popular Model for Each Manufacturer",
             text='model')  # Display the model name on the bar

# Customize plot appearance
fig.update_traces(textposition='outside')
fig.update_layout(xaxis_title="Manufacturer",
                  yaxis_title="Count",
                  showlegend=False)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Checking whether feature has how many values for each brand

plot = 'drivetrain'

# Calculate value counts
value_counts = df[plot].value_counts().reset_index()
value_counts.columns = [plot, 'Count']  # Rename columns for better visualization

# Create bar plot with plotly
fig = px.bar(value_counts, x=plot, y='Count', title="Value Counts Plot", text='Count')

# Customize appearance (optional)
fig.update_traces(textposition='outside')  # Show count numbers outside the bars
fig.update_layout(xaxis_title=plot, yaxis_title="Count", showlegend=False)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### There are lot of similarities in the names of drivetrain, for example Front-wheel Drive, FWD, Front-Wheel Drive, Front Wheel Drive is a same thing.
#
#  We can fix this by the use of regex.

# %%
df['drivetrain'].value_counts()
# Out:
# drivetrain
# Front-wheel Drive                                              241432
# All-wheel Drive                                                230219
# Four-wheel Drive                                               157082
# Rear-wheel Drive                                                97437
# FWD                                                              6450
# AWD                                                              3586
# 4WD                                                              1923
# RWD                                                              1758
# All-Wheel Drive                                                   120
# Unknown                                                           105
# Front-Wheel Drive                                                 104
# Front-Wheel Drive with Limited-Slip Differential                   44
# Four-Wheel Drive                                                   43
# ...

# %%
# Define a mapping for the changes
mapping = {
    # Set one of change
    'Front-wheel Drive': 'Front Wheel Drive',
    'FWD': 'Front Wheel Drive',
    'Front-Wheel Drive': 'Front Wheel Drive',
    'Front Wheel Drive': 'Front Wheel Drive',
    '4x2': 'Front Wheel Drive',
    '2WD': 'Front Wheel Drive',

    # Set two of change
    'All-wheel Drive': 'All Wheel Drive',
    'AWD': 'All Wheel Drive',
    'All-Wheel Drive': 'All Wheel Drive',
    'All Wheel Drive': 'All Wheel Drive',

    # Set three of change
    'Four-wheel Drive': 'Four Wheel Drive',
    'Four-Wheel Drive': 'Four Wheel Drive',
    '4WD': 'Four Wheel Drive',
    'Four Wheel Drive': 'Four Wheel Drive',
    '4x4': 'Four Wheel Drive',
    '4X4': 'Four Wheel Drive',

    # Set four of change
    'Rear-wheel Drive': 'Rear Wheel Drive',
    'RWD': 'Rear Wheel Drive',
    'Rear-Wheel Drive': 'Rear Wheel Drive',
    'Rear Wheel Drive': 'Rear Wheel Drive'
}

# Replace values based on mapping, keep others unchanged
df['standardized_drivetrain'] = df['drivetrain'].replace(mapping)

# %%
df['standardized_drivetrain'].value_counts()
# Out:
# standardized_drivetrain
# Front Wheel Drive                                              248006
# All Wheel Drive                                                233936
# Four Wheel Drive                                               159078
# Rear Wheel Drive                                                99237
# Unknown                                                           105
# Front-Wheel Drive with Limited-Slip Differential                   44
# Four-Wheel Drive with Locking and Limited-Slip Differential        42
# All-Wheel Drive with Locking and Limited-Slip Differential         33
# All-Wheel Drive with Locking Differential                          20
# Rear-Wheel Drive with Limited-Slip Differential                    12
# Four-Wheel Drive with Locking Differential                          6
# Engine: 2.4L GDI DOHC 16V I4 -inc: dual CVVT                        5
# Engine: Lambda II 3.8L GDI DOHC V6 w/Dual CVVT                      1
# ...

# %% [markdown]
# ### So far we were able to shrink the number of unique values of differnt drivetrain which were ultimately making same meaning.

# %%
# Checking whether feature has how many values for each brand

plot = 'standardized_drivetrain'

# Calculate value counts
value_counts = df[plot].value_counts().reset_index()
value_counts.columns = [plot, 'Count']  # Rename columns for better visualization

# Create bar plot with plotly
fig = px.bar(value_counts, x=plot, y='Count', title="Value Counts Plot", text='Count')

# Customize appearance (optional)
fig.update_traces(textposition='outside')  # Show count numbers outside the bars
fig.update_layout(xaxis_title=plot, yaxis_title="Count", showlegend=False)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Checking whether feature has how many values for each brand

plot = 'accidents_or_damage'

# Calculate value counts
value_counts = df[plot].value_counts().reset_index()
value_counts.columns = [plot, 'Count']  # Rename columns for better visualization

# Create bar plot with plotly
fig = px.bar(value_counts, x=plot, y='Count', title="Value Counts Plot", text='Count')

# Customize appearance (optional)
fig.update_traces(textposition='outside')  # Show count numbers outside the bars
fig.update_layout(xaxis_title=plot, yaxis_title="Count", showlegend=False)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Checking whether feature has how many values for each brand

plot = 'one_owner'

# Calculate value counts
value_counts = df[plot].value_counts().reset_index()
value_counts.columns = [plot, 'Count']  # Rename columns for better visualization

# Create bar plot with plotly
fig = px.bar(value_counts, x=plot, y='Count', title="Value Counts Plot", text='Count')

# Customize appearance (optional)
fig.update_traces(textposition='outside')  # Show count numbers outside the bars
fig.update_layout(xaxis_title=plot, yaxis_title="Count", showlegend=False)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Checking whether feature has how many values for each brand

plot = 'personal_use_only'

# Calculate value counts
value_counts = df[plot].value_counts().reset_index()
value_counts.columns = [plot, 'Count']  # Rename columns for better visualization

# Create bar plot with plotly
fig = px.bar(value_counts, x=plot, y='Count', title="Value Counts Plot", text='Count')

# Customize appearance (optional)
fig.update_traces(textposition='outside')  # Show count numbers outside the bars
fig.update_layout(xaxis_title=plot, yaxis_title="Count", showlegend=False)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['manufacturer', 'model', 'year', 'mileage', 'engine', 'transmission',
#        'drivetrain', 'fuel_type', 'mpg', 'exterior_color', 'interior_color',
#        'accidents_or_damage', 'one_owner', 'personal_use_only', 'seller_name',
#        'seller_rating', 'driver_rating', 'driver_reviews_num', 'price_drop',
#        'price', 'standardized_drivetrain'],
#       dtype='object')

# %%
# Checking whether feature has how many values for each brand

plot = 'standardized_drivetrain'

# Calculate value counts
value_counts = df[plot].value_counts().reset_index()
value_counts.columns = [plot, 'Count']  # Rename columns for better visualization

# Create bar plot with plotly
fig = px.bar(value_counts, x=plot, y='Count', title="Value Counts Plot", text='Count')

# Customize appearance (optional)
fig.update_traces(textposition='outside')  # Show count numbers outside the bars
fig.update_layout(xaxis_title=plot, yaxis_title="Count", showlegend=False)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # While handling the missing values, it is observed that the data has a high number of variations in the value because some of the car manufacturers are the most expensive compared to others. For example, their car's MPG is much lower than the others, so in the future, a conventional approach would create a lot of biases in the output or may lead to failure in the results. So, the further approach is to divide the dataset into individual manufacturers and do a separate analysis based on their characteristics. This way, the values that we generate to fill in the place of missing values for a particular manufacturer will not influence the other manufacturer's cars, and it works vice versa with every other feature. Then, in the end, we can put the records in the same dataset if there is a need to do so.
